# %%
    # !git clone https://github.com/Dmitry348/Lab2.git
# Out:
# Cloning into 'Lab2'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 7 (delta 0), reused 7 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (7/7), 4.85 KiB | 1.62 MiB/s, done.

# %%
    # !python Lab2/transfer_learning.py
# Out:
# Начало работы программы...
#
# Загрузка датасета CIFAR-10...
# 100% 170M/170M [00:04<00:00, 42.5MB/s]
# Загружено 50000 изображений для обучения
# Загружено 10000 изображений для тестирования
#
# Используется устройство: cuda
# Загрузка предобученной модели ResNet50...
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100% 97.8M/97.8M [00:00<00:00, 180MB/s]
# Модель успешно инициализирована и перемещена на cuda
#
# Начало процесса обучения...
#
# Эпоха [1/10]
# Обучение: 100% 1563/1563 [02:54<00:00,  8.96it/s, loss=0.8814]
# Валидация: 100% 313/313 [00:32<00:00,  9.62it/s, loss=0.6077]
# Результаты эпохи 1:
# Время выполнения: 206.91 сек
# Train Loss: 0.8243, Train Acc: 71.50%
# Val Loss: 0.6256, Val Acc: 78.39%
# Сохранена новая лучшая модель (val_loss: 0.6256)
#
# Эпоха [2/10]
# Обучение: 100% 1563/1563 [02:54<00:00,  8.98it/s, loss=0.6207]
# ...
